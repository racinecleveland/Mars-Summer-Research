# %%
import numpy as np
import matplotlib.pyplot as plt
## !pip install muldoon

from scipy.stats import mode

from muldoon.met_timeseries import PressureTimeseries
from muldoon.utils import *
from muldoon.read_data import *
# Out:
# Requirement already satisfied: muldoon in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (1.3.10)
# Requirement already satisfied: numpy in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from muldoon) (2.3.5)
# Requirement already satisfied: pds4-tools in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from muldoon) (1.4)
# Requirement already satisfied: emcee in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from muldoon) (3.1.6)
# Requirement already satisfied: matplotlib in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from muldoon) (3.10.6)
# Requirement already satisfied: scipy in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from muldoon) (1.16.3)
# Requirement already satisfied: astropy in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from muldoon) (7.1.1)
# Requirement already satisfied: pandas in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from muldoon) (2.3.3)
# Requirement already satisfied: statsmodels in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from muldoon) (0.14.5)
# Requirement already satisfied: pyerfa>=2.0.1.1 in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from astropy->muldoon) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.9.29.0.35.48 in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from astropy->muldoon) (0.2025.11.10.0.38.31)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from astropy->muldoon) (6.0.3)
# Requirement already satisfied: packaging>=22.0.0 in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from astropy->muldoon) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from matplotlib->muldoon) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from matplotlib->muldoon) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from matplotlib->muldoon) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from matplotlib->muldoon) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from matplotlib->muldoon) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from matplotlib->muldoon) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from matplotlib->muldoon) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->muldoon) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from pandas->muldoon) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from pandas->muldoon) (2025.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\racinecleveland\appdata\local\anaconda3\lib\site-packages (from statsmodels->muldoon) (1.0.1)

# %%
## File name must be changed to the correct file path per sol
filename = (
    "https://pds-atmospheres.nmsu.edu/PDS/data/PDS4/Mars2020/"
    "mars2020_meda/data_derived_env/"
    "sol_0420_0539/sol_0485/"
    "WE__0485___________DER_PS__________________P01.CSV"
)
time, pressure = read_Perseverance_PS_data(filename)
# plt.scatter(time, pressure)

times, pressures = break_at_gaps(time, pressure)

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.set_xlabel("Time (s)")
ax.set_ylabel("Pressure (Pa)")

for i in range(len(times)):
#     plt.axvline(time[0:-1][gaps][i])
    ax.scatter(times[i], pressures[i], marker='.')
ax.grid(True)
# Out:
# Processing file: https://pds-atmospheres.nmsu.edu/PDS/data/PDS4/Mars2020/mars2020_meda/data_derived_env/sol_0420_0539/sol_0485/WE__0485___________DER_PS__________________P01.CSV
# ===================================================================

# %%
mt = PressureTimeseries(time, pressure)

window_size = 500./3600 # window size is 500 seconds
mt.detrend_timeseries_boxcar(window_size)

fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111)
ax.scatter(mt.time, mt.detrended_data, marker='.')
ax.grid(True)
ax.set_xlabel("Time (s)")
ax.set_ylabel("Pressure (Pa)")
# Out:
# Text(0, 0.5, 'Pressure (Pa)')

# %%
matched_filter_width = 2.*mt.sampling
matched_filter_depth = 1./np.pi
distance_between_peaks = 35
detection_threshold = 7

conv = mt.apply_lorentzian_matched_filter(matched_filter_width, matched_filter_depth)
vortices = mt.find_vortices(detection_threshold=detection_threshold, distance=distance_between_peaks)

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)

ax.plot(mt.time, mt.convolution, ls='', marker='.')
ax.axhline(detection_threshold)
ax.set_xlabel("Time (s)")
ax.set_ylabel("Pressure (Pa)")

for i in range(len(mt.peak_indices)):
    ax.axvline(mt.time[mt.peak_indices[i]], color="orange", zorder=-1)

# %%
## Change sol number here too

mt.fit_all_vortices(filepath="./WE__0485");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 ## Change sol number here too
# ----> 3 mt.fit_all_vortices(filepath="./WE__0485");
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\muldoon\met_timeseries.py:340, in PressureTimeseries.fit_all_vortices(self, filepath, figsize, aspect_ratio, pressure_units, time_units, vortex_time_units)
#     338     raise ValueError("Run find_vortices first!")
#     339 if(len(self.vortices) == 0):
# --> 340     raise ValueError("There are no vortices!")
#     342 self.popts = list()
#     343 self.uncs = list()
#
# ValueError: There are no vortices!

# %%
# Make final conditioned data figure
mt.make_conditioned_data_figure(which_vortex=0);
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Make final conditioned data figure
# ----> 2 mt.make_conditioned_data_figure(which_vortex=0);
#       3 plt.tight_layout()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\muldoon\met_timeseries.py:522, in PressureTimeseries.make_conditioned_data_figure(self, which_vortex, fig, figsize, aspect_ratio, pressure_units, time_units, vortex_time_units, write_filename)
#     520     raise ValueError("Run find_vortices first!")
#     521 if(self.popts is None):
# --> 522     raise ValueError("Run fit_all_vortices first!")
#     524 if(fig is None):
#     525     fig = plt.figure(figsize=(figsize[0]*aspect_ratio, figsize[1]))
#
# ValueError: Run fit_all_vortices first!
