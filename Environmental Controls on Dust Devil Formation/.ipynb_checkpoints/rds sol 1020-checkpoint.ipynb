# %%
import pandas as pd
import requests
from pathlib import Path

# %%
csv_path = "E:/mars2020_meda_calibrated_RDS.csv"
urn_col = "URN"

out_dir = Path("E:/rds_data")
out_dir.mkdir(exist_ok=True)

base_url = "https://atmos.nmsu.edu/PDS/data/PDS4/Mars2020/mars2020_meda/data_calibrated_env"
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 urn_col = "URN"
#       4 out_dir = Path("E:/rds_data")
# ----> 5 out_dir.mkdir(exist_ok=True)
#       7 base_url = "https://atmos.nmsu.edu/PDS/data/PDS4/Mars2020/mars2020_meda/data_calibrated_env"
#
# File ~\miniconda3\envs\muldoon\Lib\pathlib\__init__.py:1011, in Path.mkdir(self, mode, parents, exist_ok)
#    1007 """
#    1008 Create a new directory at this given path.
#    1009 """
#    1010 try:
# -> 1011     os.mkdir(self, mode)
#    1012 except FileNotFoundError:
#    1013     if not parents or self.parent == self:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'E:\\rds_data'
