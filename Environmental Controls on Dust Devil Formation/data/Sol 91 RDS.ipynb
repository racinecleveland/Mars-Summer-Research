# %%
import matplotlib.pyplot as plt
import numpy as np

from local_utils import *
from muldoon.utils import *

# %%
desired_sol = 91
time, RDS_data = get_RDS_data(desired_sol, data_dir="./")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 desired_sol = 91
# ----> 2 time, RDS_data = get_RDS_data(desired_sol, data_dir="./")
#
# File ~\OneDrive\Documents\GitHub\Mars-Summer-Research\Environmental Controls on Dust Devil Formation\data\local_utils.py:288, in get_RDS_data(sol, data_dir)
#     273 """
#     274 Returns the time in LTST and RDS dataset for a given sol
#     275
#    (...)    281     time, RDS_data
#     282 """
#     284 RDS_data_file = data_dir +\
#     285         "sol_*%i/WE*%i*RDS*.CSV" %\
#     286         (sol, sol)
# --> 288 filename = glob(RDS_data_file)[0]
#     290 RDS_data = np.genfromtxt(filename, delimiter=',',
#     291         names=True, dtype=None)
#     292 time = make_seconds_since_midnight(filename)
#
# IndexError: list index out of range

# %%
#LAT 1 is the blind sensor 
#plt.plot(time, RDS_data['RDS_LAT_1'])
plt.plot(time, RDS_data['RDS_LAT_2'])
plt.plot(time, RDS_data['RDS_LAT_3'])
plt.plot(time, RDS_data['RDS_LAT_4'])
plt.plot(time, RDS_data['RDS_LAT_5'])
plt.plot(time, RDS_data['RDS_LAT_6'])
plt.plot(time, RDS_data['RDS_LAT_7'])
plt.plot(time, RDS_data['RDS_LAT_8'])
#plt.show()
plt.ylabel('Irradiance')
plt.xlabel('Time (hours)')
color = 'RDS_LAT_%i'
plt.legend(['LAT_2', 'LAT_3', 'LAT_4', 'LAT_5', 'LAT_6', 'LAT_7', 'LAT_8'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 #LAT 1 is the blind sensor
#       2 #plt.plot(time, RDS_data['RDS_LAT_1'])
# ----> 3 plt.plot(time, RDS_data['RDS_LAT_2'])
#       4 plt.plot(time, RDS_data['RDS_LAT_3'])
#       5 plt.plot(time, RDS_data['RDS_LAT_4'])
#
# NameError: name 'time' is not defined
