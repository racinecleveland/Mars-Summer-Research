# %%
import matplotlib.pyplot as plt
import numpy as np
import glob

from local_utils import *
from muldoon.utils import *

# %%
desired_sol = 90
RDS_data_file = f"WE__00{desired_sol}___________CAL_RDS_________________P01.csv"
time, RDS_data = get_RDS_data(desired_sol,RDS_data_file, data_dir="./")
#print(RDS_data.dtype.names)
# Out:
# Processing file: WE__0090___________CAL_RDS_________________P01.csv
# ...

# %%
#LAT 1 is the blind sensor 
#plt.plot(time, RDS_data['RDS_LAT_1'])
plt.plot(time, RDS_data['RDS_LAT_2'])
plt.plot(time, RDS_data['RDS_LAT_3'])
plt.plot(time, RDS_data['RDS_LAT_4'])
plt.plot(time, RDS_data['RDS_LAT_5'])
plt.plot(time, RDS_data['RDS_LAT_6'])
plt.plot(time, RDS_data['RDS_LAT_7'])
plt.plot(time, RDS_data['RDS_LAT_8'])
#plt.show()
plt.ylabel('Irradiance')
plt.xlabel('Time (hours)')
#color = 'RDS_LAT_%i'
plt.legend(['LAT_2', 'LAT_3', 'LAT_4', 'LAT_5', 'LAT_6', 'LAT_7', 'LAT_8'])

# %%
#plt.plot(time, RDS_data['RDS_TOP_1'])
plt.plot(time, RDS_data['RDS_TOP_2'])
plt.plot(time, RDS_data['RDS_TOP_3'])
plt.plot(time, RDS_data['RDS_TOP_4'])
plt.plot(time, RDS_data['RDS_TOP_5'])
plt.plot(time, RDS_data['RDS_TOP_6'])
plt.plot(time, RDS_data['RDS_TOP_7'])
plt.plot(time, RDS_data['RDS_TOP_8'])
#plt.show()
plt.ylabel('Irradiance')
plt.xlabel('Time(hours)')
plt.legend(['TOP_2', 'TOP_3', 'TOP_4', 'TOP_5', 'TOP_6', 'TOP_7', 'TOP_8'])

# %%
# plt.plot(time, RDS_data['RDS_LAT_2'])
# plt.plot(time, RDS_data['RDS_LAT_3'])
# plt.plot(time, RDS_data['RDS_LAT_4'])
# plt.plot(time, RDS_data['RDS_LAT_6'])
# plt.plot(time, RDS_data['RDS_LAT_7'])
# plt.plot(time, RDS_data['RDS_LAT_8'])

# plt.plot(time, RDS_data['RDS_TOP_2'])
# plt.plot(time, RDS_data['RDS_TOP_3'])
# plt.plot(time, RDS_data['RDS_TOP_4'])
# plt.plot(time, RDS_data['RDS_TOP_5'])
# plt.plot(time, RDS_data['RDS_TOP_6'])
# plt.plot(time, RDS_data['RDS_TOP_7'])
# plt.plot(time, RDS_data['RDS_TOP_8'])
