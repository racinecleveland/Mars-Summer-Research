# %%
from PIL import Image
import numpy as np

img = np.asarray(Image.open('stinkbug.webp'))
#print(repr(img))
imgplot = plt.imshow(img)

'''
x = np.arange(50)
y = np.arange(50)

img_2 = np.outer(y, x)   # (50, 50)

plt.imshow(img_2)'''

lum_img = img[:, :, 0]
#plt.imshow(lum_img)
imgplot = plt.imshow(lum_img, cmap="hot")
imgplot.set_cmap('nipy_spectral')
plt.colorbar()

plt.show()

# %%
#plt.hist(lum_img.ravel(), bins=range(256), fc='k', ec='k')
plt.imshow(lum_img, clim=(0, 50))
imgplot.set_clim(0, 50)

plt.show()

# %%
img = Image.open('stinkbug.webp')
img.thumbnail((16, 16))  # resizes image in-place
imgplot = plt.imshow(img, interpolation="bilinear")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 img = Image.open('stinkbug.webp')
# ----> 2 img.thumbnail((16, 16), interpolation="bilinear")  # resizes image in-place
#       3 imgplot = plt.imshow(img)
#       4 plt.show()
#
# TypeError: Image.thumbnail() got an unexpected keyword argument 'interpolation'
