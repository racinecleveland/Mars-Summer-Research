# %%
import numpy as np
import matplotlib.pyplot as plt
##!pip install muldoon 

from scipy.stats import mode

from muldoon.met_timeseries import PressureTimeseries
from muldoon.utils import *
from muldoon.read_data import *

# %%
## File name must be changed to the correct file path per sol
filename = (
    "https://pds-atmospheres.nmsu.edu/PDS/data/PDS4/Mars2020/"
    "mars2020_meda/data_derived_env/"
    "sol_1140_1259/sol_1141/"
    "WE__1141___________DER_PS__________________P01.CSV"
)
time, pressure = read_Perseverance_PS_data(filename)
# plt.scatter(time, pressure)

times, pressures = break_at_gaps(time, pressure)

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.set_xlabel("Time (s)")
ax.set_ylabel("Pressure (Pa)")

for i in range(len(times)):
#     plt.axvline(time[0:-1][gaps][i])
    ax.scatter(times[i], pressures[i], marker='.')
ax.grid(True)
# Out:
# Processing file: https://pds-atmospheres.nmsu.edu/PDS/data/PDS4/Mars2020/mars2020_meda/data_derived_env/sol_1140_1259/sol_1141/WE__1141___________DER_PS__________________P01.CSV
# ===================================================================

# %%
mt = PressureTimeseries(time, pressure)

window_size = 500./3600 # window size is 500 seconds
mt.detrend_timeseries_boxcar(window_size)

fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111)
ax.scatter(mt.time, mt.detrended_data, marker='.')
ax.grid(True)
ax.set_xlabel("Time (s)")
ax.set_ylabel("Pressure (Pa)")
# Out:
# Text(0, 0.5, 'Pressure (Pa)')

# %%
matched_filter_width = 2.*mt.sampling
matched_filter_depth = 1./np.pi
distance_between_peaks = 35
detection_threshold = 7

conv = mt.apply_lorentzian_matched_filter(matched_filter_width, matched_filter_depth)
vortices = mt.find_vortices(detection_threshold=detection_threshold, distance=distance_between_peaks)

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)

ax.plot(mt.time, mt.convolution, ls='', marker='.')
ax.axhline(detection_threshold)
ax.set_xlabel("Time (s)")
ax.set_ylabel("Pressure (Pa)")

for i in range(len(mt.peak_indices)):
    ax.axvline(mt.time[mt.peak_indices[i]], color="orange", zorder=-1)

# %%
import shutil
import os

#Reduce spam of .csv files from muldoon API but keep it running and making the graphs
#It still needs a file path to load the graphs
dataFolder = r"C:\Users\Vrijz\Downloads\PressureData"

#To save the graphs locally for easy word use
graphsFolder = r"C:\Users\Vrijz\Downloads\PressureGraphs"

## Change sol number here too
mt.fit_all_vortices(filepath=os.path.join(dataFolder, "WE__1142"))


for i in plt.get_fignums():
    fig = plt.figure(i)
    fig.savefig(
        os.path.join(graphsFolder, f"vortex_fit_{i-1}.png"),
        dpi=300,
        bbox_inches='tight'
    )
# Out:
# fit_all_vortices: vortex 4 couldn't be fit!
# fit_all_vortices: vortex 5 couldn't be fit!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 26
#      23 os.makedirs(graphsFolder, exist_ok=True)
#      25 ## Change sol number here too
# ---> 26 mt.fit_all_vortices(filepath=os.path.join(dataFolder, "WE__1142"))
#      29 for i in plt.get_fignums():
#      30     fig = plt.figure(i)
#
# File ~\anaconda3\Lib\site-packages\muldoon\met_timeseries.py:346, in PressureTimeseries.fit_all_vortices(self, filepath, figsize, aspect_ratio, pressure_units, time_units, vortex_time_units)
#     343 self.uncs = list()
#     344 for i in range(len(self.vortices)):
#     345     # Estimate initial parameters
# --> 346     init_params = self._determine_init_params(self.vortices[i])
#     348     # Estimate bounds
#     349     bounds = self._determine_bounds(self.vortices[i], init_params)
#
# File ~\anaconda3\Lib\site-packages\muldoon\met_timeseries.py:425, in PressureTimeseries._determine_init_params(self, vortex, init_baseline, init_slope, init_t0, init_DeltaP, init_Gamma)
#     422 y = vortex["data"]
#     424 # Initial fit to background trend
# --> 425 fit_params = np.polyfit(x, y, 1)
#     426 detrended_y = y - np.polyval(fit_params, x)
#     428 if(init_baseline is None):
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\_polynomial_impl.py:645, in polyfit(x, y, deg, rcond, full, w, cov)
#     643     raise TypeError("expected 1D vector for x")
#     644 if x.size == 0:
# --> 645     raise TypeError("expected non-empty vector for x")
#     646 if y.ndim < 1 or y.ndim > 2:
#     647     raise TypeError("expected 1D or 2D array for y")
#
# TypeError: expected non-empty vector for x

# %%
import os
import shutil

# Make final conditioned data figure
finalFourGraphsFolder = r"C:\Users\Vrijz\Downloads\FinalFourGraphs"

#Clear and recreate 
shutil.rmtree(finalFourGraphsFolder)
os.makedirs(finalFourGraphsFolder, exist_ok=True)

 
mt.make_conditioned_data_figure(which_vortex=1);
plt.tight_layout()

for i in plt.get_fignums():
    fig = plt.figure(i)
    fig.savefig(
        os.path.join(finalFourGraphsFolder, f"vortex_fit_{i}.png"),
        dpi=300,
        bbox_inches='tight'
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 12
#       8 shutil.rmtree(finalFourGraphsFolder)
#       9 os.makedirs(finalFourGraphsFolder, exist_ok=True)
# ---> 12 mt.make_conditioned_data_figure(which_vortex=1);
#      13 plt.tight_layout()
#      15 for i in plt.get_fignums():
#
# File ~\anaconda3\Lib\site-packages\muldoon\met_timeseries.py:522, in PressureTimeseries.make_conditioned_data_figure(self, which_vortex, fig, figsize, aspect_ratio, pressure_units, time_units, vortex_time_units, write_filename)
#     520     raise ValueError("Run find_vortices first!")
#     521 if(self.popts is None):
# --> 522     raise ValueError("Run fit_all_vortices first!")
#     524 if(fig is None):
#     525     fig = plt.figure(figsize=(figsize[0]*aspect_ratio, figsize[1]))
#
# ValueError: Run fit_all_vortices first!
